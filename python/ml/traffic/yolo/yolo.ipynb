# %%
from ultralytics import YOLO
import warnings
warnings.filterwarnings('ignore')

# %%
# Build from YAML and transfer weights
Final_model = YOLO('yolov8n.pt')  

# Training The Final Model
Result_Final_model = Final_model.train(data="/media/yassin/Nuevo vol/Datasets/yolo_traffic/data.yaml", epochs = 30, batch = 15, optimizer = 'auto')
# Out:
# New https://pypi.org/project/ultralytics/8.3.199 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.198 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=15, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/media/yassin/Nuevo vol/Datasets/yolo_traffic/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 129 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 29.2MB/s 0.2ss 0.1s<0.7s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 5.6±5.7 ms, read: 18.8±8.6 MB/s, size: 406.6 KB)
# train: Scanning /media/yassin/Nuevo vol/Datasets/yolo_traffic/train... 592 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 592/592 174.3it/s 3.4s0.0s
# train: /media/yassin/Nuevo vol/Datasets/yolo_traffic/train/00340.jpg: 1 duplicate labels removed
# train: New cache created: /media/yassin/Nuevo vol/Datasets/yolo_traffic/train.cache
# val: Fast image access ✅ (ping: 1.2±1.0 ms, read: 10.2±7.7 MB/s, size: 334.0 KB)
# val: Scanning /media/yassin/Nuevo vol/Datasets/yolo_traffic/train.cache... 592 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 592/592 556.9Kit/s 0.0s
# train: /media/yassin/Nuevo vol/Datasets/yolo_traffic/train/00340.jpg: 1 duplicate labels removed
# Plotting labels to /home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.00046875), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 6 dataloader workers
# Logging results to /home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      1.89G      1.371      4.463     0.9277         35        640: 100% ━━━━━━━━━━━━ 40/40 3.5it/s 11.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.2it/s 4.8s0.2s
#                    all        592        973   0.000158     0.0302     0.0096    0.00841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      1.91G      1.212      2.666     0.8674         15        640: 100% ━━━━━━━━━━━━ 40/40 5.5it/s 7.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.5s0.2s
#                    all        592        973          1     0.0407       0.56      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      1.92G      1.131          2     0.8706         20        640: 100% ━━━━━━━━━━━━ 40/40 6.4it/s 6.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.5it/s 4.4s0.2s
#                    all        592        973      0.894      0.635      0.801      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      1.93G      1.084       1.66     0.8601         24        640: 100% ━━━━━━━━━━━━ 40/40 6.0it/s 6.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.2s0.3s
#                    all        592        973      0.876      0.749      0.851      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      1.93G      1.057      1.495     0.8687         12        640: 100% ━━━━━━━━━━━━ 40/40 5.8it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.9s0.2s
#                    all        592        973      0.925      0.773       0.89      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      1.94G      1.005      1.255     0.8571         21        640: 100% ━━━━━━━━━━━━ 40/40 5.7it/s 7.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.8it/s 5.3s0.3s
#                    all        592        973      0.925        0.8      0.905      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      1.96G     0.9602      1.174     0.8442         16        640: 100% ━━━━━━━━━━━━ 40/40 5.2it/s 7.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.8it/s 5.3s0.2s
#                    all        592        973      0.927      0.821      0.911       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      1.97G     0.9214      1.051     0.8337         23        640: 100% ━━━━━━━━━━━━ 40/40 5.8it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.9s0.3s
#                    all        592        973      0.908      0.841      0.928      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      1.99G     0.9042     0.9723     0.8298         29        640: 100% ━━━━━━━━━━━━ 40/40 5.4it/s 7.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.4it/s 5.9s0.3s
#                    all        592        973       0.95       0.85      0.924      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.01G     0.8688     0.8865     0.8302         14        640: 100% ━━━━━━━━━━━━ 40/40 5.8it/s 6.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.9it/s 5.1s0.3s
#                    all        592        973      0.958      0.856      0.941      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.03G      0.919     0.8789     0.8421         21        640: 100% ━━━━━━━━━━━━ 40/40 6.3it/s 6.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.6s0.2s
#                    all        592        973      0.938      0.866       0.94      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.04G     0.8383      0.816      0.829         10        640: 100% ━━━━━━━━━━━━ 40/40 6.1it/s 6.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.6it/s 5.6s0.2s
#                    all        592        973      0.963      0.865      0.947      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.04G     0.8429     0.7775     0.8328         22        640: 100% ━━━━━━━━━━━━ 40/40 6.2it/s 6.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.9s0.3s
#                    all        592        973      0.949      0.873      0.949      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      2.04G     0.8516     0.7607     0.8304         12        640: 100% ━━━━━━━━━━━━ 40/40 6.1it/s 6.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.6s0.2s
#                    all        592        973       0.96      0.873      0.952      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.04G     0.8456     0.7308      0.821         18        640: 100% ━━━━━━━━━━━━ 40/40 5.3it/s 7.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.9it/s 5.2s0.3s
#                    all        592        973      0.946      0.904      0.964      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.04G     0.7896     0.6924     0.8151         16        640: 100% ━━━━━━━━━━━━ 40/40 5.7it/s 7.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.9s0.2s
#                    all        592        973      0.967       0.89      0.964      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.04G     0.8037     0.6744     0.8232         18        640: 100% ━━━━━━━━━━━━ 40/40 5.4it/s 7.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.6it/s 5.5s0.2s
#                    all        592        973      0.944      0.895      0.959      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.04G     0.7875     0.6567     0.8165         16        640: 100% ━━━━━━━━━━━━ 40/40 6.3it/s 6.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.5it/s 4.4s0.2s
#                    all        592        973      0.963      0.912      0.969      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.04G     0.7945     0.6633      0.821         11        640: 100% ━━━━━━━━━━━━ 40/40 6.3it/s 6.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.7s0.2s
#                    all        592        973      0.979      0.897      0.971      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.04G     0.7758     0.6264     0.8176         18        640: 100% ━━━━━━━━━━━━ 40/40 6.2it/s 6.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.5it/s 5.7s0.2s
#                    all        592        973      0.977      0.916      0.973      0.774
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.05G     0.7377     0.6639      0.809          7        640: 100% ━━━━━━━━━━━━ 40/40 5.3it/s 7.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.9it/s 5.1s0.3s
#                    all        592        973       0.96      0.905      0.969      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.05G      0.749      0.637     0.8123          7        640: 100% ━━━━━━━━━━━━ 40/40 6.4it/s 6.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.0it/s 5.0s0.2s
#                    all        592        973      0.962      0.894      0.972      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.05G     0.7186     0.5965     0.8035          9        640: 100% ━━━━━━━━━━━━ 40/40 5.5it/s 7.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.0it/s 4.9s0.2s
#                    all        592        973      0.943      0.913      0.969      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.05G     0.7009     0.5882     0.8056          8        640: 100% ━━━━━━━━━━━━ 40/40 6.5it/s 6.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.6s0.3s
#                    all        592        973      0.944      0.931      0.977      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.05G     0.6968     0.5686     0.8118         12        640: 100% ━━━━━━━━━━━━ 40/40 6.1it/s 6.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.8s0.2s
#                    all        592        973      0.963      0.922      0.979      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.05G     0.6968     0.5524     0.8076         15        640: 100% ━━━━━━━━━━━━ 40/40 5.2it/s 7.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.5it/s 4.4s0.2s
#                    all        592        973      0.955      0.938      0.976      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.05G     0.6737      0.537     0.7929         12        640: 100% ━━━━━━━━━━━━ 40/40 5.8it/s 6.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.1it/s 4.8s0.2s
#                    all        592        973      0.978      0.917      0.979      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.05G     0.6782     0.5323      0.799         13        640: 100% ━━━━━━━━━━━━ 40/40 6.5it/s 6.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.5it/s 4.4s0.2s
#                    all        592        973      0.963      0.935      0.979      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.05G     0.6498     0.5152     0.7975         11        640: 100% ━━━━━━━━━━━━ 40/40 5.5it/s 7.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.6it/s 4.4s0.2s
#                    all        592        973      0.959      0.935      0.981      0.794
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.05G     0.6306     0.5028     0.7885          8        640: 100% ━━━━━━━━━━━━ 40/40 6.8it/s 5.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.7it/s 4.2s0.2s
#                    all        592        973      0.965      0.938      0.983      0.802
#
# 30 epochs completed in 0.103 hours.
# Optimizer stripped from /home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3/weights/last.pt, 6.2MB
# Optimizer stripped from /home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3/weights/best.pt, 6.2MB
#
# Validating /home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.198 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                    all        592        973      0.965      0.938      0.982      0.802
#            prohibitory        312        453      0.984      0.969      0.991      0.826
#                 danger        139        172      0.977      0.969       0.99      0.838
#              mandatory        115        132      0.945      0.905      0.972       0.77
#                  other        168        216      0.955      0.907      0.976      0.773
# Speed: 0.1ms preprocess, 1.5ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to /home/yassin/code/Miscellaneous/python/ml/traffic/yolo/runs/detect/train3

# %%
Valid_model = YOLO('best.pt')

# Evaluating the model on the validset
metrics = Valid_model.val(split = 'val')

# final results 
print("precision(B): ", metrics.results_dict["metrics/precision(B)"])
print("metrics/recall(B): ", metrics.results_dict["metrics/recall(B)"])
print("metrics/mAP50(B): ", metrics.results_dict["metrics/mAP50(B)"])
print("metrics/mAP50-95(B): ", metrics.results_dict["metrics/mAP50-95(B)"])
# Out:
# Ultralytics 8.3.198 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 1.7±0.3 ms, read: 88.8±13.8 MB/s, size: 349.7 KB)
# val: Scanning /media/yassin/Nuevo vol/Datasets/yolo_traffic_3/train.cache... 592 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 592/592 848.3Kit/s 0.0s
# train: /media/yassin/Nuevo vol/Datasets/yolo_traffic_3/train/00340.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 4.5it/s 8.2s0.1s
#                    all        592        973      0.955      0.941       0.98      0.804
#            prohibitory        312        453      0.976      0.956      0.992      0.836
#                 danger        139        172      0.983      0.953      0.987      0.826
#              mandatory        115        132      0.959      0.917      0.969      0.773
#                  other        168        216      0.904       0.94      0.972       0.78
# Speed: 0.5ms preprocess, 2.5ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /home/yassin/code/Miscellaneous/python/ml/traffic/runs/detect/val
# precision(B):  0.9552662082271348
# metrics/recall(B):  0.9414549357998072
# metrics/mAP50(B):  0.9800756720644066
# metrics/mAP50-95(B):  0.8036254546075998
